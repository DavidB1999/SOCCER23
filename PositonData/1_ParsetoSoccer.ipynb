# %%
from Parse_DFL import write_dfl_xml_to_soccer
from floodlight.io import dfl
import numpy as np
import pandas as pd
import itertools as it
from findIndex import findIndex
import fileinput
import os
import csv
import glob

# %%
game_overview = pd.read_csv('Output/GameOverview2.csv')


ROOT = os.getcwd() # returns current working directory of a process.

pos_data = (r"PositionData") # creates a raw string which treats backslash (\) as a literal character. 

# create matchday folders
# only necessary once!
#for MD in range(1,35):
#    matchday = str(MD) 
#    os.mkdir(''.join(['./SOCCER_FILES/Matchday', matchday])) # create folder for each match and matchday

# create match folders!
# only necessary once!
#for pos_file in os.listdir(pos_data):
#    if pos_file.startswith('DFL') and 'DFL-MAT-0027W0' not in pos_file and 'DFL-MAT-0027W1' not in pos_file:
#        mn = pos_file[-18:-4] # cut the matchname!
#        md = str(game_overview.Matchday[game_overview.MI_Name == mn].iloc[0])
#        os.mkdir(''.join(['./SOCCER_FILES/Matchday', md, '/',  mn])) # make folder for each match and matchday



for pos_file in os.listdir(pos_data):
    if pos_file.startswith('DFL') and 'DFL-MAT-0027W0' not in pos_file and 'DFL-MAT-0027W1' not in pos_file:
        mn = pos_file[-18:-4] # cut the matchname!
        md = str(game_overview.Matchday[game_overview.MI_Name == mn].iloc[0])
        print(md)
        position_file = os.path.join(pos_data, pos_file)
        # find the matching match info
        matching_files = glob.glob(''.join(['Matchinfo/*',mn, '*']))
        if len(matching_files) != 1:   # should be only one matchinfo file matching the game 
            print('Matchinfo Error')
        else:
            matchinfo = matching_files[0]
            # parse data via floodlight parser
            xy_objects, possession_objects, ballstatus_objects, teamsheets, pitch = dfl.read_position_data_xml(filepath_positions=position_file,
                      filepath_mat_info=matchinfo)
            write_dfl_xml_to_soccer(xy_objects, teamsheets, md, game_overview, mn) 
            # this function includes the saving of the files!
# Out:
# 1
# DFL-MAT-00277X
# DFL-MAT-00277X-
# Player 0 did not play in this half and will be deleted completely later on!
# Player 1 did not play in this half and will be deleted completely later on!
# Player 5 did not play in this half and will be deleted completely later on!
# Player 11 did not play in this half and will be deleted completely later on!
# Player 15 did not play in this half and will be deleted completely later on!
# Player 16 did not play in this half and will be deleted completely later on!
# Player 17 did not play in this half and will be deleted completely later on!
# []
# []
# SOCCER_FILES/Matchday1/DFL-MAT-00277X/DFL-MAT-00277X-positionen-home-HT0
# Player 0 did not play in this half and will be deleted completely later on!
# Player 3 did not play in this half and will be deleted completely later on!
# Player 6 did not play in this half and will be deleted completely later on!
# Player 9 did not play in this half and will be deleted completely later on!
# Player 13 did not play in this half and will be deleted completely later on!
# Player 14 did not play in this half and will be deleted completely later on!
# Player 17 did not play in this half and will be deleted completely later on!
# []
# []
# SOCCER_FILES/Matchday1/DFL-MAT-00277X/DFL-MAT-00277X-positionen-guest-HT0
# 1  of DFL-MAT-00277X- had to be reflected
# Player 0 did not play in this half and will be deleted completely later on!
# Player 5 did not play in this half and will be deleted completely later on!
# Player 15 did not play in this half and will be deleted completely later on!
# Player 17 did not play in this half and will be deleted completely later on!
# [[8, 'RV', 42268], [9, 'LV', 48733], [12, 'MZ', 27787]]
# [[1, 'RV', 42268], [11, 'HR', 27787], [16, 'LV', 48733]]
# [[0, 2]]
# [1, 'RV', 42268]
# [8, 'RV', 42268]
# 42268
# 8
# []
# []
# 8
# 1
# ['1_x', '1_y']
# ['8_x', '8_y']
# [[2, 2]]
# [11, 'HR', 27787]
# [12, 'MZ', 27787]
# 27787
# 12
# [8]
# [1]
# 12
# 11
# ['11_x', '11_y']
# ['12_x', '12_y']
# [[1, 2]]
# [16, 'LV', 48733]
# [9, 'LV', 48733]
# 48733
# 9
# [8, 12]
# [1, 11]
# 9
# 16
# ['16_x', '16_y']
# ['9_x', '9_y']
# SOCCER_FILES/Matchday1/DFL-MAT-00277X/DFL-MAT-00277X-positionen-home-HT1
# 1  of DFL-MAT-00277X- had to be reflected
# Player 3 did not play in this half and will be deleted completely later on!
# Player 9 did not play in this half and will be deleted completely later on!
# Player 13 did not play in this half and will be deleted completely later on!
# Player 17 did not play in this half and will be deleted completely later on!
# [[1, 'STZ', 27263], [8, 'LM', 63869], [15, 'DMZ', 42320]]
# [[0, 'STZ', 63869], [6, 'LM', 27263], [14, 'HR', 42320]]
# [[1, 2]]
# [0, 'STZ', 63869]
# [8, 'LM', 63869]
# 63869
# 8
# []
# []
# 8
# 0
# ['0_x', '0_y']
# ['8_x', '8_y']
# [[0, 2]]
# [6, 'LM', 27263]
# [1, 'STZ', 27263]
# 27263
# 1
# [8]
# [0]
# 1
# 6
# ['6_x', '6_y']
# ['1_x', '1_y']
# [[2, 2]]
# [14, 'HR', 42320]
# [15, 'DMZ', 42320]
# 42320
# 15
# [8, 1]
# [0, 6]
# 15
# 14
# ['14_x', '14_y']
# ['15_x', '15_y']
# SOCCER_FILES/Matchday1/DFL-MAT-00277X/DFL-MAT-00277X-positionen-guest-HT1
# 1  of DFL-MAT-00277X- had to be reflected
# 1
# DFL-MAT-00277Y
# DFL-MAT-00277Y-
# 0  of DFL-MAT-00277Y- had to be reflected
# Player 2 did not play in this half and will be deleted completely later on!
# Player 3 did not play in this half and will be deleted completely later on!
# Player 5 did not play in this half and will be deleted completely later on!
# Player 7 did not play in this half and will be deleted completely later on!
# Player 9 did not play in this half and will be deleted completely later on!
# Player 12 did not play in this half and will be deleted completely later on!
# Player 17 did not play in this half and will be deleted completely later on!
# []
# []
# SOCCER_FILES/Matchday1/DFL-MAT-00277Y/DFL-MAT-00277Y-positionen-home-HT0
# 0  of DFL-MAT-00277Y- had to be reflected
# Player 2 did not play in this half and will be deleted completely later on!
# Player 3 did not play in this half and will be deleted completely later on!
# Player 4 did not play in this half and will be deleted completely later on!
# Player 7 did not play in this half and will be deleted completely later on!
# Player 12 did not play in this half and will be deleted completely later on!
# Player 13 did not play in this half and will be deleted completely later on!
# Player 16 did not play in this half and will be deleted completely later on!
# []
# []
# SOCCER_FILES/Matchday1/DFL-MAT-00277Y/DFL-MAT-00277Y-positionen-guest-HT0
# 0  of DFL-MAT-00277Y- had to be reflected
# Player 2 did not play in this half and will be deleted completely later on!
# Player 7 did not play in this half and will be deleted completely later on!
# Player 9 did not play in this half and will be deleted completely later on!
# Player 17 did not play in this half and will be deleted completely later on!
# [[10, 'DML', 60701], [13, 'DMR', 19778], [14, 'RV', 46776]]
# [[3, 'RV', 46776], [5, 'HL', 60701], [12, 'DMZ', 19778]]
# [[2, 2]]
# [3, 'RV', 46776]
# [14, 'RV', 46776]
# 46776
# 14
# []
# []
# 14
# 3
# ['3_x', '3_y']
# ['14_x', '14_y']
# [[0, 2]]
# [5, 'HL', 60701]
# [10, 'DML', 60701]
# 60701
# 10
# [14]
# [3]
# 10
# 5
# ['5_x', '5_y']
# ['10_x', '10_y']
# [[1, 2]]
# [12, 'DMZ', 19778]
# [13, 'DMR', 19778]
# 19778
# 13
# [14, 10]
# [3, 5]
# 13
# 12
# ['12_x', '12_y']
# ['13_x', '13_y']
# SOCCER_FILES/Matchday1/DFL-MAT-00277Y/DFL-MAT-00277Y-positionen-home-HT1
# Player 4 did not play in this half and will be deleted completely later on!
# Player 12 did not play in this half and will be deleted completely later on!
# Player 13 did not play in this half and will be deleted completely later on!
# Player 16 did not play in this half and will be deleted completely later on!
# [[0, 'STZ', 60426], [8, 'RM', 53093], [15, 'HL', 38295]]
# [[2, 'ZO', 60426], [3, 'LM', 38295], [7, 'STZ', 53093]]
# [[0, 2]]
# [2, 'ZO', 60426]
# [0, 'STZ', 60426]
# 60426
# 0
# []
# []
# 0
# 2
# ['2_x', '2_y']
# ['0_x', '0_y']
# [[2, 2]]
# [3, 'LM', 38295]
# [15, 'HL', 38295]
# 38295
# 15
# [0]
# [2]
# 15
# 3
# ['3_x', '3_y']
# ['15_x', '15_y']
# [[1, 2]]
# [7, 'STZ', 53093]
# [8, 'RM', 53093]
# 53093
# 8
# [0, 15]
# [2, 3]
# 8
# 7
# ['7_x', '7_y']
# ['8_x', '8_y']
# SOCCER_FILES/Matchday1/DFL-MAT-00277Y/DFL-MAT-00277Y-positionen-guest-HT1
# 1
# DFL-MAT-00277Z
# DFL-MAT-00277Z-
# 0  of DFL-MAT-00277Z- had to be reflected
# Player 0 did not play in this half and will be deleted completely later on!
# Player 2 did not play in this half and will be deleted completely later on!
# Player 3 did not play in this half and will be deleted completely later on!
# Player 6 did not play in this half and will be deleted completely later on!
# Player 9 did not play in this half and will be deleted completely later on!
# Player 11 did not play in this half and will be deleted completely later on!
# Player 13 did not play in this half and will be deleted completely later on!
# []
# []
# SOCCER_FILES/Matchday1/DFL-MAT-00277Z/DFL-MAT-00277Z-positionen-home-HT0
# 0  of DFL-MAT-00277Z- had to be reflected
# Player 1 did not play in this half and will be deleted completely later on!
# Player 5 did not play in this half and will be deleted completely later on!
# Player 6 did not play in this half and will be deleted completely later on!
# Player 7 did not play in this half and will be deleted completely later on!
# Player 9 did not play in this half and will be deleted completely later on!
# Player 10 did not play in this half and will be deleted completely later on!
# Player 12 did not play in this half and will be deleted completely later on!
# []
# []
# SOCCER_FILES/Matchday1/DFL-MAT-00277Z/DFL-MAT-00277Z-positionen-guest-HT0
# 0  of DFL-MAT-00277Z- had to be reflected
# Player 0 did not play in this half and will be deleted completely later on!
# Player 2 did not play in this half and will be deleted completely later on!
# Player 9 did not play in this half and will be deleted completely later on!
# Player 10 did not play in this half and will be deleted completely later on!
# Player 13 did not play in this half and will be deleted completely later on!
# [[12, 'STR', 57062], [15, 'RM', 22946]]
# [[3, 'STR', 57062], [6, 'RM', 22946]]
# [[0, 2]]
# [3, 'STR', 57062]
# [12, 'STR', 57062]
# 57062
# 12
# []
# []
# 12
# 3
# ['3_x', '3_y']
# ['12_x', '12_y']
# [[1, 2]]
# [6, 'RM', 22946]
# [15, 'RM', 22946]
# 22946
# 15
# [12]
# [3]
# 15
# 6
# ['6_x', '6_y']
# ['15_x', '15_y']
# SOCCER_FILES/Matchday1/DFL-MAT-00277Z/DFL-MAT-00277Z-positionen-home-HT1
# Player 1 did not play in this half and will be deleted completely later on!
# Player 6 did not play in this half and will be deleted completely later on!
# Player 9 did not play in this half and will be deleted completely later on!
# Player 10 did not play in this half and will be deleted completely later on!
# [[13, 'STR', 27483], [15, 'STL', 27730], [17, 'DMR', 48126]]
# [[5, 'STR', 27483], [7, 'STZ', 48126], [12, 'RM', 27730]]
# [[0, 2]]
# [5, 'STR', 27483]
# [13, 'STR', 27483]
# 27483
# 13
# []
# []
# 13
# 5
# ['5_x', '5_y']
# ['13_x', '13_y']
# [[2, 2]]
# [7, 'STZ', 48126]
# [17, 'DMR', 48126]
# 48126
# 17
# [13]
# [5]
# 17
# 7
# ['7_x', '7_y']
# ['17_x', '17_y']
# [[1, 2]]
# [12, 'RM', 27730]
# [15, 'STL', 27730]
# 27730
# 15
# [13, 17]
# [5, 7]
# 15
# 12
# ['12_x', '12_y']
# ['15_x', '15_y']
# SOCCER_FILES/Matchday1/DFL-MAT-00277Z/DFL-MAT-00277Z-positionen-guest-HT1
# 1
# DFL-MAT-002780
# DFL-MAT-002780-
# Player 0 did not play in this half and will be deleted completely later on!
# Player 1 did not play in this half and will be deleted completely later on!
# Player 4 did not play in this half and will be deleted completely later on!
# Player 6 did not play in this half and will be deleted completely later on!
# Player 7 did not play in this half and will be deleted completely later on!
# Player 9 did not play in this half and will be deleted completely later on!
# Player 15 did not play in this half and will be deleted completely later on!
# []
# []
# SOCCER_FILES/Matchday1/DFL-MAT-002780/DFL-MAT-002780-positionen-home-HT0
# Player 2 did not play in this half and will be deleted completely later on!
# Player 3 did not play in this half and will be deleted completely later on!
# Player 5 did not play in this half and will be deleted completely later on!
# Player 9 did not play in this half and will be deleted completely later on!
# Player 10 did not play in this half and will be deleted completely later on!
# Player 11 did not play in this half and will be deleted completely later on!
# Player 14 did not play in this half and will be deleted completely later on!
# []
# []
# SOCCER_FILES/Matchday1/DFL-MAT-002780/DFL-MAT-002780-positionen-guest-HT0
# 1  of DFL-MAT-002780- had to be reflected
# Player 0 did not play in this half and will be deleted completely later on!
# Player 4 did not play in this half and will be deleted completely later on!
# Player 7 did not play in this half and will be deleted completely later on!
# Player 9 did not play in this half and will be deleted completely later on!
# [[8, 'STZ', 59889], [13, 'ORM', 46893], [17, 'ZO', 66783]]
# [[1, 'ZO', 66783], [6, 'ORM', 46893], [15, 'STZ', 59889]]
# [[2, 2]]
# [1, 'ZO', 66783]
# [17, 'ZO', 66783]
# 66783
# 17
# []
# []
# 17
# 1
# ['1_x', '1_y']
# ['17_x', '17_y']
# [[1, 2]]
# [6, 'ORM', 46893]
# [13, 'ORM', 46893]
# 46893
# 13
# [17]
# [1]
# 13
# 6
# ['6_x', '6_y']
# ['13_x', '13_y']
# [[0, 2]]
# [15, 'STZ', 59889]
# [8, 'STZ', 59889]
# 59889
# 8
# [17, 13]
# [1, 6]
# 8
# 15
# ['15_x', '15_y']
# ['8_x', '8_y']
# SOCCER_FILES/Matchday1/DFL-MAT-002780/DFL-MAT-002780-positionen-home-HT1
# 1  of DFL-MAT-002780- had to be reflected
# Player 2 did not play in this half and will be deleted completely later on!
# Player 3 did not play in this half and will be deleted completely later on!
# Player 9 did not play in this half and will be deleted completely later on!
# Player 11 did not play in this half and will be deleted completely later on!
# Player 14 did not play in this half and will be deleted completely later on!
# [[0, 'HR', 31765], [17, 'RM', 31245]]
# [[5, 'STR', 31765], [10, 'RM', 31245]]
# [[0, 2]]
# [5, 'STR', 31765]
# [0, 'HR', 31765]
# 31765
# 0
# []
# []
# 0
# 5
# ['5_x', '5_y']
# ['0_x', '0_y']
# [[1, 2]]
# [10, 'RM', 31245]
# [17, 'RM', 31245]
# 31245
# 17
# [0]
# [5]
# 17
# 10
# ['10_x', '10_y']
# ['17_x', '17_y']
# SOCCER_FILES/Matchday1/DFL-MAT-002780/DFL-MAT-002780-positionen-guest-HT1
# 1  of DFL-MAT-002780- had to be reflected
# 1
# DFL-MAT-002781
# DFL-MAT-002781-
# Player 2 did not play in this half and will be deleted completely later on!
# Player 4 did not play in this half and will be deleted completely later on!
# Player 7 did not play in this half and will be deleted completely later on!
# Player 8 did not play in this half and will be deleted completely later on!
# Player 9 did not play in this half and will be deleted completely later on!
# Player 11 did not play in this half and will be deleted completely later on!
# Player 14 did not play in this half and will be deleted completely later on!
# []
# []
# SOCCER_FILES/Matchday1/DFL-MAT-002781/DFL-MAT-002781-positionen-home-HT0
# Player 0 did not play in this half and will be deleted completely later on!
# Player 1 did not play in this half and will be deleted completely later on!
# Player 4 did not play in this half and will be deleted completely later on!
# Player 10 did not play in this half and will be deleted completely later on!
# Player 13 did not play in this half and will be deleted completely later on!
# Player 14 did not play in this half and will be deleted completely later on!
# Player 15 did not play in this half and will be deleted completely later on!
# []
# []
# SOCCER_FILES/Matchday1/DFL-MAT-002781/DFL-MAT-002781-positionen-guest-HT0
# 1  of DFL-MAT-002781- had to be reflected
# Player 7 did not play in this half and will be deleted completely later on!
# Player 9 did not play in this half and will be deleted completely later on!
# Player 11 did not play in this half and will be deleted completely later on!
# Player 14 did not play in this half and will be deleted completely later on!
# [[0, 'STL', 36412], [3, 'LM', 43446], [15, 'STR', 61841]]
# [[2, 'ZO', 61841], [4, 'STR', 36412], [8, 'LM', 43446]]
# [[2, 2]]
# [2, 'ZO', 61841]
# [15, 'STR', 61841]
# 61841
# 15
# []
# []
# 15
# 2
# ['2_x', '2_y']
# ['15_x', '15_y']
# [[0, 2]]
# [4, 'STR', 36412]
# [0, 'STL', 36412]
# 36412
# 0
# [15]
# [2]
# 0
# 4
# ['4_x', '4_y']
# ['0_x', '0_y']
# [[1, 2]]
# [8, 'LM', 43446]
# [3, 'LM', 43446]
# 43446
# 3
# [15, 0]
# [2, 4]
# 3
# 8
# ['8_x', '8_y']
# ['3_x', '3_y']
# SOCCER_FILES/Matchday1/DFL-MAT-002781/DFL-MAT-002781-positionen-home-HT1
# 1  of DFL-MAT-002781- had to be reflected
# Player 0 did not play in this half and will be deleted completely later on!
# Player 1 did not play in this half and will be deleted completely later on!
# Player 4 did not play in this half and will be deleted completely later on!
# Player 13 did not play in this half and will be deleted completely later on!
# [[5, 'ZO', 36129], [6, 'ORM', 60183], [7, 'RV', 17063]]
# [[10, 'RM', 60183], [14, 'DMR', 36129], [15, 'RV', 17063]]
# [[1, 2]]
# [10, 'RM', 60183]
# [6, 'ORM', 60183]
# 60183
# 6
# []
# []
# 6
# 10
# ['10_x', '10_y']
# ['6_x', '6_y']
# [[0, 2]]
# [14, 'DMR', 36129]
# [5, 'ZO', 36129]
# 36129
# 5
# [6]
# [10]
# 5
# 14
# ['14_x', '14_y']
# ['5_x', '5_y']
# [[2, 2]]
# [15, 'RV', 17063]
# [7, 'RV', 17063]
# 17063
# 7
# [6, 5]
# [10, 14]
# 7
# 15
# ['15_x', '15_y']
# ['7_x', '7_y']
# SOCCER_FILES/Matchday1/DFL-MAT-002781/DFL-MAT-002781-positionen-guest-HT1
# 1  of DFL-MAT-002781- had to be reflected
# 1
# DFL-MAT-002782
# DFL-MAT-002782-
# Player 2 did not play in this half and will be deleted completely later on!
# Player 3 did not play in this half and will be deleted completely later on!
# Player 4 did not play in this half and will be deleted completely later on!
# Player 7 did not play in this half and will be deleted completely later on!
# Player 10 did not play in this half and will be deleted completely later on!
# Player 12 did not play in this half and will be deleted completely later on!
# Player 15 did not play in this half and will be deleted completely later on!
# []
# []
# SOCCER_FILES/Matchday1/DFL-MAT-002782/DFL-MAT-002782-positionen-home-HT0
# Player 0 did not play in this half and will be deleted completely later on!
# Player 6 did not play in this half and will be deleted completely later on!
# Player 7 did not play in this half and will be deleted completely later on!
# Player 8 did not play in this half and will be deleted completely later on!
# Player 12 did not play in this half and will be deleted completely later on!
# Player 14 did not play in this half and will be deleted completely later on!
# Player 17 did not play in this half and will be deleted completely later on!
# []
# []
# SOCCER_FILES/Matchday1/DFL-MAT-002782/DFL-MAT-002782-positionen-guest-HT0
# 1  of DFL-MAT-002782- had to be reflected
# Player 2 did not play in this half and will be deleted completely later on!
# Player 7 did not play in this half and will be deleted completely later on!
# Player 12 did not play in this half and will be deleted completely later on!
# Player 15 did not play in this half and will be deleted completely later on!
# [[5, 'ZO', 31716], [14, 'ORM', 31097], [16, 'DMR', 30120]]
# [[3, 'RV', 30120], [4, 'ORM', 31097], [10, 'STZ', 31716]]
# [[2, 2]]
# [3, 'RV', 30120]
# [16, 'DMR', 30120]
# 30120
# 16
# []
# []
# 16
# 3
# ['3_x', '3_y']
# ['16_x', '16_y']
# [[1, 2]]
# [4, 'ORM', 31097]
# [14, 'ORM', 31097]
# 31097
# 14
# [16]
# [3]
# 14
# 4
# ['4_x', '4_y']
# ['14_x', '14_y']
# [[0, 2]]
# [10, 'STZ', 31716]
# [5, 'ZO', 31716]
# 31716
# 5
# [16, 14]
# [3, 4]
# 5
# 10
# ['10_x', '10_y']
# ['5_x', '5_y']
# SOCCER_FILES/Matchday1/DFL-MAT-002782/DFL-MAT-002782-positionen-home-HT1
# 1  of DFL-MAT-002782- had to be reflected
# Player 0 did not play in this half and will be deleted completely later on!
# Player 6 did not play in this half and will be deleted completely later on!
# Player 7 did not play in this half and will be deleted completely later on!
# Player 8 did not play in this half and will be deleted completely later on!
# [[2, 'RA', 30630], [10, 'HL', 53222], [16, 'STZ', 68146]]
# [[12, 'DML', 53222], [14, 'RA', 30630], [17, 'RA', 68146]]
# [[1, 2]]
# [12, 'DML', 53222]
# [10, 'HL', 53222]
# 53222
# 10
# []
# []
# 10
# 12
# ['12_x', '12_y']
# ['10_x', '10_y']
# [[0, 2]]
# [14, 'RA', 30630]
# [2, 'RA', 30630]
# 30630
# 2
# [10]
# [12]
# 2
# 14
# ['14_x', '14_y']
# ['2_x', '2_y']
# [[2, 2]]
# [17, 'RA', 68146]
# [16, 'STZ', 68146]
# 68146
# 16
# [10, 2]
# [12, 14]
# 16
# 17
# ['17_x', '17_y']
# ['16_x', '16_y']
# SOCCER_FILES/Matchday1/DFL-MAT-002782/DFL-MAT-002782-positionen-guest-HT1
# 1  of DFL-MAT-002782- had to be reflected
# 1
# DFL-MAT-002783
# DFL-MAT-002783-
# 0  of DFL-MAT-002783- had to be reflected
# Player 1 did not play in this half and will be deleted completely later on!
# Player 6 did not play in this half and will be deleted completely later on!
# Player 7 did not play in this half and will be deleted completely later on!
# Player 10 did not play in this half and will be deleted completely later on!
# Player 11 did not play in this half and will be deleted completely later on!
# Player 12 did not play in this half and will be deleted completely later on!
# Player 14 did not play in this half and will be deleted completely later on!
# []
# []
# SOCCER_FILES/Matchday1/DFL-MAT-002783/DFL-MAT-002783-positionen-home-HT0
# 0  of DFL-MAT-002783- had to be reflected
# Player 0 did not play in this half and will be deleted completely later on!
# Player 2 did not play in this half and will be deleted completely later on!
# Player 5 did not play in this half and will be deleted completely later on!
# Player 9 did not play in this half and will be deleted completely later on!
# Player 12 did not play in this half and will be deleted completely later on!
# Player 13 did not play in this half and will be deleted completely later on!
# Player 17 did not play in this half and will be deleted completely later on!
# []
# []
# SOCCER_FILES/Matchday1/DFL-MAT-002783/DFL-MAT-002783-positionen-guest-HT0
# 0  of DFL-MAT-002783- had to be reflected
# Player 1 did not play in this half and will be deleted completely later on!
# Player 7 did not play in this half and will be deleted completely later on!
# Player 11 did not play in this half and will be deleted completely later on!
# Player 12 did not play in this half and will be deleted completely later on!
# [[0, 'DMR', 57026], [9, 'STZ', 25827], [17, 'ZO', 54067]]
# [[6, 'ORM', 25827], [10, 'LM', 54067], [14, 'HR', 57026]]
# [[1, 2]]
# [6, 'ORM', 25827]
# [9, 'STZ', 25827]
# 25827
# 9
# []
# []
# 9
# 6
# ['6_x', '6_y']
# ['9_x', '9_y']
# [[2, 2]]
# [10, 'LM', 54067]
# [17, 'ZO', 54067]
# 54067
# 17
# [9]
# [6]
# 17
# 10
# ['10_x', '10_y']
# ['17_x', '17_y']
# [[0, 2]]
# [14, 'HR', 57026]
# [0, 'DMR', 57026]
# 57026
# 0
# [9, 17]
# [6, 10]
# 0
# 14
# ['14_x', '14_y']
# ['0_x', '0_y']
# SOCCER_FILES/Matchday1/DFL-MAT-002783/DFL-MAT-002783-positionen-home-HT1
# Player 0 did not play in this half and will be deleted completely later on!
# Player 2 did not play in this half and will be deleted completely later on!
# Player 9 did not play in this half and will be deleted completely later on!
# Player 12 did not play in this half and will be deleted completely later on!
# [[3, 'ZO', 38999], [11, 'STZ', 53652], [14, 'DML', 21951]]
# [[5, 'RV', 38999], [13, 'STZ', 53652], [17, 'DMR', 21951]]
# [[0, 2]]
# [5, 'RV', 38999]
# [3, 'ZO', 38999]
# 38999
# 3
# []
# []
# 3
# 5
# ['5_x', '5_y']
# ['3_x', '3_y']
# [[1, 2]]
# [13, 'STZ', 53652]
# [11, 'STZ', 53652]
# 53652
# 11
# [3]
# [5]
# 11
# 13
# ['13_x', '13_y']
# ['11_x', '11_y']
# [[2, 2]]
# [17, 'DMR', 21951]
# [14, 'DML', 21951]
# 21951
# 14
# [3, 11]
# [5, 13]
# 14
# 17
# ['17_x', '17_y']
# ['14_x', '14_y']
# SOCCER_FILES/Matchday1/DFL-MAT-002783/DFL-MAT-002783-positionen-guest-HT1
# 1
# DFL-MAT-002784
# DFL-MAT-002784-
# Player 1 did not play in this half and will be deleted completely later on!
# Player 4 did not play in this half and will be deleted completely later on!
# Player 6 did not play in this half and will be deleted completely later on!
# Player 9 did not play in this half and will be deleted completely later on!
# Player 11 did not play in this half and will be deleted completely later on!
# Player 13 did not play in this half and will be deleted completely later on!
# Player 14 did not play in this half and will be deleted completely later on!
# []
# []
# SOCCER_FILES/Matchday1/DFL-MAT-002784/DFL-MAT-002784-positionen-home-HT0
# Player 1 did not play in this half and will be deleted completely later on!
# Player 4 did not play in this half and will be deleted completely later on!
# Player 6 did not play in this half and will be deleted completely later on!
# Player 7 did not play in this half and will be deleted completely later on!
# Player 8 did not play in this half and will be deleted completely later on!
# Player 9 did not play in this half and will be deleted completely later on!
# Player 12 did not play in this half and will be deleted completely later on!
# []
# []
# SOCCER_FILES/Matchday1/DFL-MAT-002784/DFL-MAT-002784-positionen-guest-HT0
# 1  of DFL-MAT-002784- had to be reflected
# Player 4 did not play in this half and will be deleted completely later on!
# Player 6 did not play in this half and will be deleted completely later on!
# Player 13 did not play in this half and will be deleted completely later on!
# Player 14 did not play in this half and will be deleted completely later on!
# Player 16 did not play in this half and will be deleted completely later on!
# [[3, 'HL', 29845], [10, 'LA', 50744]]
# [[1, 'LA', 50744], [9, 'HL', 29845]]
# [[1, 2]]
# [1, 'LA', 50744]
# [10, 'LA', 50744]
# 50744
# 10
# []
# []
# 10
# 1
# ['1_x', '1_y']
# ['10_x', '10_y']
# [[0, 2]]
# [9, 'HL', 29845]
# [3, 'HL', 29845]
# 29845
# 3
# [10]
# [1]
# 3
# 9
# ['9_x', '9_y']
# ['3_x', '3_y']
# SOCCER_FILES/Matchday1/DFL-MAT-002784/DFL-MAT-002784-positionen-home-HT1
# 1  of DFL-MAT-002784- had to be reflected
# Player 1 did not play in this half and will be deleted completely later on!
# Player 6 did not play in this half and will be deleted completely later on!
# Player 7 did not play in this half and will be deleted completely later on!
# Player 8 did not play in this half and will be deleted completely later on!
# [[0, 'IVL', 26853], [10, 'STL', 55001], [17, 'STR', 61132]]
# [[4, 'STL', 61132], [9, 'STL', 55001], [12, 'ORM', 26853]]
# [[2, 2]]
# [4, 'STL', 61132]
# [17, 'STR', 61132]
# 61132
# 17
# []
# []
# 17
# 4
# ['4_x', '4_y']
# ['17_x', '17_y']
# [[1, 2]]
# [9, 'STL', 55001]
# [10, 'STL', 55001]
# 55001
# 10
# [17]
# [4]
# 10
# 9
# ['9_x', '9_y']
# ['10_x', '10_y']
# [[0, 2]]
# [12, 'ORM', 26853]
# [0, 'IVL', 26853]
# 26853
# 0
# [17, 10]
# [4, 9]
# 0
# 12
# ['12_x', '12_y']
# ['0_x', '0_y']
# SOCCER_FILES/Matchday1/DFL-MAT-002784/DFL-MAT-002784-positionen-guest-HT1
# 1  of DFL-MAT-002784- had to be reflected
# 1
# DFL-MAT-002785
# DFL-MAT-002785-
# Player 1 did not play in this half and will be deleted completely later on!
# Player 4 did not play in this half and will be deleted completely later on!
# Player 8 did not play in this half and will be deleted completely later on!
# Player 10 did not play in this half and will be deleted completely later on!
# Player 11 did not play in this half and will be deleted completely later on!
# Player 14 did not play in this half and will be deleted completely later on!
# Player 16 did not play in this half and will be deleted completely later on!
# []
# []
# SOCCER_FILES/Matchday1/DFL-MAT-002785/DFL-MAT-002785-positionen-home-HT0
# Player 1 did not play in this half and will be deleted completely later on!
# Player 6 did not play in this half and will be deleted completely later on!
# Player 10 did not play in this half and will be deleted completely later on!
# Player 11 did not play in this half and will be deleted completely later on!
# Player 14 did not play in this half and will be deleted completely later on!
# Player 16 did not play in this half and will be deleted completely later on!
# Player 17 did not play in this half and will be deleted completely later on!
# []
# []
# SOCCER_FILES/Matchday1/DFL-MAT-002785/DFL-MAT-002785-positionen-guest-HT0
# 1  of DFL-MAT-002785- had to be reflected
# Player 1 did not play in this half and will be deleted completely later on!
# Player 4 did not play in this half and will be deleted completely later on!
# Player 14 did not play in this half and will be deleted completely later on!
# Player 16 did not play in this half and will be deleted completely later on!
# [[0, 'ORM', 15044], [6, 'OLM', 67059], [9, 'IVR', 50825], [12, 'STZ', 53184]]
# [[8, 'OLM', 67059], [10, 'RM', 15044], [11, 'IVR', 53184]]
# more suboffs as subons Probably just a red card or injury post 3 subs
# [[1, 2]]
# [8, 'OLM', 67059]
# [6, 'OLM', 67059]
# 67059
# 6
# []
# []
# 6
# 8
# ['8_x', '8_y']
# ['6_x', '6_y']
# [[0, 2]]
# [10, 'RM', 15044]
# [0, 'ORM', 15044]
# 15044
# 0
# [6]
# [8]
# 0
# 10
# ['10_x', '10_y']
# ['0_x', '0_y']
# [[3, 2]]
# [11, 'IVR', 53184]
# [12, 'STZ', 53184]
# 53184
# 12
# [6, 0]
# [8, 10]
# 12
# 11
# ['11_x', '11_y']
# ['12_x', '12_y']
# SOCCER_FILES/Matchday1/DFL-MAT-002785/DFL-MAT-002785-positionen-home-HT1
# 1  of DFL-MAT-002785- had to be reflected
# Player 1 did not play in this half and will be deleted completely later on!
# Player 4 did not play in this half and will be deleted completely later on!
# Player 6 did not play in this half and will be deleted completely later on!
# Player 11 did not play in this half and will be deleted completely later on!
# Player 14 did not play in this half and will be deleted completely later on!
# [[2, 'DMR', 42476], [8, 'LV', 24089]]
# [[16, 'LV', 24089], [17, 'DMR', 42476]]
# [[1, 2]]
# [16, 'LV', 24089]
# [8, 'LV', 24089]
# 24089
# 8
# []
# []
# 8
# 16
# ['16_x', '16_y']
# ['8_x', '8_y']
# [[0, 2]]
# [17, 'DMR', 42476]
# [2, 'DMR', 42476]
# 42476
# 2
# [8]
# [16]
# 2
# 17
# ['17_x', '17_y']
# ['2_x', '2_y']
# SOCCER_FILES/Matchday1/DFL-MAT-002785/DFL-MAT-002785-positionen-guest-HT1
# 1  of DFL-MAT-002785- had to be reflected
# 2
# DFL-MAT-002786
# DFL-MAT-002786-
# 0  of DFL-MAT-002786- had to be reflected
# Player 1 did not play in this half and will be deleted completely later on!
# Player 3 did not play in this half and will be deleted completely later on!
# Player 4 did not play in this half and will be deleted completely later on!
# Player 8 did not play in this half and will be deleted completely later on!
# Player 11 did not play in this half and will be deleted completely later on!
# Player 16 did not play in this half and will be deleted completely later on!
# [[2, 'RM', 4116]]
# [[6, 'RM', 4116]]
# [[0, 2]]
# [6, 'RM', 4116]
# [2, 'RM', 4116]
# 4116
# 2
# []
# []
# 2
# 6
# ['6_x', '6_y']
# ['2_x', '2_y']
# SOCCER_FILES/Matchday2/DFL-MAT-002786/DFL-MAT-002786-positionen-home-HT0
# 0  of DFL-MAT-002786- had to be reflected
# Player 4 did not play in this half and will be deleted completely later on!
# Player 5 did not play in this half and will be deleted completely later on!
# Player 6 did not play in this half and will be deleted completely later on!
# Player 13 did not play in this half and will be deleted completely later on!
# Player 15 did not play in this half and will be deleted completely later on!
# Player 16 did not play in this half and will be deleted completely later on!
# Player 17 did not play in this half and will be deleted completely later on!
# []
# []
# SOCCER_FILES/Matchday2/DFL-MAT-002786/DFL-MAT-002786-positionen-guest-HT0
# 0  of DFL-MAT-002786- had to be reflected
# Player 2 did not play in this half and will be deleted completely later on!
# Player 3 did not play in this half and will be deleted completely later on!
# Player 4 did not play in this half and will be deleted completely later on!
# Player 11 did not play in this half and will be deleted completely later on!
# Player 16 did not play in this half and will be deleted completely later on!
# [[7, 'LV', 63486], [15, 'LM', 39172]]
# [[1, 'RV', 63486], [8, 'STR', 39172]]
# [[0, 2]]
# [1, 'RV', 63486]
# [7, 'LV', 63486]
# 63486
# 7
# []
# []
# 7
# 1
# ['1_x', '1_y']
# ['7_x', '7_y']
# [[1, 2]]
# [8, 'STR', 39172]
# [15, 'LM', 39172]
# 39172
# 15
# [7]
# [1]
# 15
# 8
# ['8_x', '8_y']
# ['15_x', '15_y']
# SOCCER_FILES/Matchday2/DFL-MAT-002786/DFL-MAT-002786-positionen-home-HT1
# Player 5 did not play in this half and will be deleted completely later on!
# Player 6 did not play in this half and will be deleted completely later on!
# Player 15 did not play in this half and will be deleted completely later on!
# Player 16 did not play in this half and will be deleted completely later on!
# [[2, 'STZ', 52395], [3, 'OLM', 60381], [14, 'DML', 31367]]
# [[4, 'DMR', 31367], [13, 'STZ', 52395], [17, 'ORM', 60381]]
# [[2, 2]]
# [4, 'DMR', 31367]
# [14, 'DML', 31367]
# 31367
# 14
# []
# []
# 14
# 4
# ['4_x', '4_y']
# ['14_x', '14_y']
# [[0, 2]]
# [13, 'STZ', 52395]
# [2, 'STZ', 52395]
# 52395
# 2
# [14]
# [4]
# 2
# 13
# ['13_x', '13_y']
# ['2_x', '2_y']
# [[1, 2]]
# [17, 'ORM', 60381]
# [3, 'OLM', 60381]
# 60381
# 3
# [14, 2]
# [4, 13]
# 3
# 17
# ['17_x', '17_y']
# ['3_x', '3_y']
# SOCCER_FILES/Matchday2/DFL-MAT-002786/DFL-MAT-002786-positionen-guest-HT1
# 2
# DFL-MAT-002787
# DFL-MAT-002787-
# Player 2 did not play in this half and will be deleted completely later on!
# Player 3 did not play in this half and will be deleted completely later on!
# Player 5 did not play in this half and will be deleted completely later on!
# Player 10 did not play in this half and will be deleted completely later on!
# Player 11 did not play in this half and will be deleted completely later on!
# Player 13 did not play in this half and will be deleted completely later on!
# Player 15 did not play in this half and will be deleted completely later on!
# []
# []
# SOCCER_FILES/Matchday2/DFL-MAT-002787/DFL-MAT-002787-positionen-home-HT0
# Player 2 did not play in this half and will be deleted completely later on!
# Player 3 did not play in this half and will be deleted completely later on!
# Player 4 did not play in this half and will be deleted completely later on!
# Player 6 did not play in this half and will be deleted completely later on!
# Player 10 did not play in this half and will be deleted completely later on!
# Player 13 did not play in this half and will be deleted completely later on!
# Player 15 did not play in this half and will be deleted completely later on!
# []
# []
# SOCCER_FILES/Matchday2/DFL-MAT-002787/DFL-MAT-002787-positionen-guest-HT0
# 1  of DFL-MAT-002787- had to be reflected
# Player 2 did not play in this half and will be deleted completely later on!
# Player 5 did not play in this half and will be deleted completely later on!
# Player 10 did not play in this half and will be deleted completely later on!
# Player 13 did not play in this half and will be deleted completely later on!
# [[6, 'ORM', 14098], [8, 'STZ', 31831], [14, 'DMR', 61257]]
# [[3, 'LV', 61257], [11, 'STR', 14098], [15, 'ZO', 31831]]
# [[2, 2]]
# [3, 'LV', 61257]
# [14, 'DMR', 61257]
# 61257
# 14
# []
# []
# 14
# 3
# ['3_x', '3_y']
# ['14_x', '14_y']
# [[0, 2]]
# [11, 'STR', 14098]
# [6, 'ORM', 14098]
# 14098
# 6
# [14]
# [3]
# 6
# 11
# ['11_x', '11_y']
# ['6_x', '6_y']
# [[1, 2]]
# [15, 'ZO', 31831]
# [8, 'STZ', 31831]
# 31831
# 8
# [14, 6]
# [3, 11]
# 8
# 15
# ['15_x', '15_y']
# ['8_x', '8_y']
# SOCCER_FILES/Matchday2/DFL-MAT-002787/DFL-MAT-002787-positionen-home-HT1
# 1  of DFL-MAT-002787- had to be reflected
# Player 2 did not play in this half and will be deleted completely later on!
# Player 3 did not play in this half and will be deleted completely later on!
# Player 4 did not play in this half and will be deleted completely later on!
# Player 13 did not play in this half and will be deleted completely later on!
# [[0, 'HL', 38620], [5, 'MZ', 22953], [9, 'LA', 23481]]
# [[6, 'HL', 22953], [10, 'LA', 23481], [15, 'HR', 38620]]
# [[1, 2]]
# [6, 'HL', 22953]
# [5, 'MZ', 22953]
# 22953
# 5
# []
# []
# 5
# 6
# ['6_x', '6_y']
# ['5_x', '5_y']
# [[2, 2]]
# [10, 'LA', 23481]
# [9, 'LA', 23481]
# 23481
# 9
# [5]
# [6]
# 9
# 10
# ['10_x', '10_y']
# ['9_x', '9_y']
# [[0, 2]]
# [15, 'HR', 38620]
# [0, 'HL', 38620]
# 38620
# 0
# [5, 9]
# [6, 10]
# 0
# 15
# ['15_x', '15_y']
# ['0_x', '0_y']
# SOCCER_FILES/Matchday2/DFL-MAT-002787/DFL-MAT-002787-positionen-guest-HT1
# 1  of DFL-MAT-002787- had to be reflected
# 2
# DFL-MAT-002788
# DFL-MAT-002788-
# Player 2 did not play in this half and will be deleted completely later on!
# Player 5 did not play in this half and will be deleted completely later on!
# Player 6 did not play in this half and will be deleted completely later on!
# Player 7 did not play in this half and will be deleted completely later on!
# Player 10 did not play in this half and will be deleted completely later on!
# Player 11 did not play in this half and will be deleted completely later on!
# Player 15 did not play in this half and will be deleted completely later on!
# []
# []
# SOCCER_FILES/Matchday2/DFL-MAT-002788/DFL-MAT-002788-positionen-home-HT0
# Player 0 did not play in this half and will be deleted completely later on!
# Player 1 did not play in this half and will be deleted completely later on!
# Player 8 did not play in this half and will be deleted completely later on!
# Player 9 did not play in this half and will be deleted completely later on!
# Player 12 did not play in this half and will be deleted completely later on!
# Player 14 did not play in this half and will be deleted completely later on!
# [[7, 'IVR', 53711]]
# [[11, 'ORM', 53711]]
# [[0, 2]]
# [11, 'ORM', 53711]
# [7, 'IVR', 53711]
# 53711
# 7
# []
# []
# 7
# 11
# ['11_x', '11_y']
# ['7_x', '7_y']
# SOCCER_FILES/Matchday2/DFL-MAT-002788/DFL-MAT-002788-positionen-guest-HT0
# 1  of DFL-MAT-002788- had to be reflected
# Player 5 did not play in this half and will be deleted completely later on!
# Player 7 did not play in this half and will be deleted completely later on!
# Player 10 did not play in this half and will be deleted completely later on!
# Player 11 did not play in this half and will be deleted completely later on!
# [[1, 'RM', 41296], [4, 'LM', 22788], [9, 'LV', 19667], [16, 'STZ', 49961]]
# [[2, 'RM', 41296], [6, 'LV', 22788], [15, 'LM', 49961]]
# more suboffs as subons Probably just a red card or injury post 3 subs
# [[0, 2]]
# [2, 'RM', 41296]
# [1, 'RM', 41296]
# 41296
# 1
# []
# []
# 1
# 2
# ['2_x', '2_y']
# ['1_x', '1_y']
# [[1, 2]]
# [6, 'LV', 22788]
# [4, 'LM', 22788]
# 22788
# 4
# [1]
# [2]
# 4
# 6
# ['6_x', '6_y']
# ['4_x', '4_y']
# [[3, 2]]
# [15, 'LM', 49961]
# [16, 'STZ', 49961]
# 49961
# 16
# [1, 4]
# [2, 6]
# 16
# 15
# ['15_x', '15_y']
# ['16_x', '16_y']
# SOCCER_FILES/Matchday2/DFL-MAT-002788/DFL-MAT-002788-positionen-home-HT1
# 1  of DFL-MAT-002788- had to be reflected
# Player 1 did not play in this half and will be deleted completely later on!
# Player 2 did not play in this half and will be deleted completely later on!
# Player 7 did not play in this half and will be deleted completely later on!
# Player 8 did not play in this half and will be deleted completely later on!
# Player 9 did not play in this half and will be deleted completely later on!
# Player 14 did not play in this half and will be deleted completely later on!
# [[17, 'DMR', 27496]]
# [[12, 'STR', 27496]]
# [[0, 2]]
# [12, 'STR', 27496]
# [17, 'DMR', 27496]
# 27496
# 17
# []
# []
# 17
# 12
# ['12_x', '12_y']
# ['17_x', '17_y']
# SOCCER_FILES/Matchday2/DFL-MAT-002788/DFL-MAT-002788-positionen-guest-HT1
# 1  of DFL-MAT-002788- had to be reflected
# 2
# DFL-MAT-002789
# DFL-MAT-002789-
# Player 1 did not play in this half and will be deleted completely later on!
# Player 2 did not play in this half and will be deleted completely later on!
# Player 4 did not play in this half and will be deleted completely later on!
# Player 8 did not play in this half and will be deleted completely later on!
# Player 9 did not play in this half and will be deleted completely later on!
# Player 10 did not play in this half and will be deleted completely later on!
# Player 11 did not play in this half and will be deleted completely later on!
# []
# []
# SOCCER_FILES/Matchday2/DFL-MAT-002789/DFL-MAT-002789-positionen-home-HT0
# Player 2 did not play in this half and will be deleted completely later on!
# Player 4 did not play in this half and will be deleted completely later on!
# Player 8 did not play in this half and will be deleted completely later on!
# Player 13 did not play in this half and will be deleted completely later on!
# Player 14 did not play in this half and will be deleted completely later on!
# Player 15 did not play in this half and will be deleted completely later on!
# Player 16 did not play in this half and will be deleted completely later on!
# []
# []
# SOCCER_FILES/Matchday2/DFL-MAT-002789/DFL-MAT-002789-positionen-guest-HT0
# 1  of DFL-MAT-002789- had to be reflected
# Player 2 did not play in this half and will be deleted completely later on!
# Player 8 did not play in this half and will be deleted completely later on!
# Player 9 did not play in this half and will be deleted completely later on!
# Player 11 did not play in this half and will be deleted completely later on!
# [[5, 'DML', 25658], [6, 'ZO', 50142], [12, 'ORM', 25306]]
# [[1, 'RM', 25306], [4, 'OLM', 50142], [10, 'HR', 25658]]
# [[2, 2]]
# [1, 'RM', 25306]
# [12, 'ORM', 25306]
# 25306
# 12
# []
# []
# 12
# 1
# ['1_x', '1_y']
# ['12_x', '12_y']
# [[1, 2]]
# [4, 'OLM', 50142]
# [6, 'ZO', 50142]
# 50142
# 6
# [12]
# [1]
# 6
# 4
# ['4_x', '4_y']
# ['6_x', '6_y']
# [[0, 2]]
# [10, 'HR', 25658]
# [5, 'DML', 25658]
# 25658
# 5
# [12, 6]
# [1, 4]
# 5
# 10
# ['10_x', '10_y']
# ['5_x', '5_y']
# SOCCER_FILES/Matchday2/DFL-MAT-002789/DFL-MAT-002789-positionen-home-HT1
# 1  of DFL-MAT-002789- had to be reflected
# Player 2 did not play in this half and will be deleted completely later on!
# Player 4 did not play in this half and will be deleted completely later on!
# Player 8 did not play in this half and will be deleted completely later on!
# Player 15 did not play in this half and will be deleted completely later on!
# [[0, 'STL', 31892], [5, 'STR', 49668], [7, 'DML', 61595]]
# [[13, 'STZ', 49668], [14, 'LV', 61595], [16, 'ZO', 31892]]
# [[1, 2]]
# [13, 'STZ', 49668]
# [5, 'STR', 49668]
# 49668
# 5
# []
# []
# 5
# 13
# ['13_x', '13_y']
# ['5_x', '5_y']
# [[2, 2]]
# [14, 'LV', 61595]
# [7, 'DML', 61595]
# 61595
# 7
# [5]
# [13]
# 7
# 14
# ['14_x', '14_y']
# ['7_x', '7_y']
# [[0, 2]]
# [16, 'ZO', 31892]
# [0, 'STL', 31892]
# 31892
# 0
# [5, 7]
# [13, 14]
# 0
# 16
# ['16_x', '16_y']
# ['0_x', '0_y']
# SOCCER_FILES/Matchday2/DFL-MAT-002789/DFL-MAT-002789-positionen-guest-HT1
# 1  of DFL-MAT-002789- had to be reflected
# 2
# DFL-MAT-00278A
# DFL-MAT-00278A-
# Player 0 did not play in this half and will be deleted completely later on!
# Player 4 did not play in this half and will be deleted completely later on!
# Player 11 did not play in this half and will be deleted completely later on!
# Player 12 did not play in this half and will be deleted completely later on!
# Player 15 did not play in this half and will be deleted completely later on!
# Player 16 did not play in this half and will be deleted completely later on!
# Player 17 did not play in this half and will be deleted completely later on!
# []
# []
# SOCCER_FILES/Matchday2/DFL-MAT-00278A/DFL-MAT-00278A-positionen-home-HT0
# Player 2 did not play in this half and will be deleted completely later on!
# Player 3 did not play in this half and will be deleted completely later on!
# Player 5 did not play in this half and will be deleted completely later on!
# Player 6 did not play in this half and will be deleted completely later on!
# Player 10 did not play in this half and will be deleted completely later on!
# Player 11 did not play in this half and will be deleted completely later on!
# Player 14 did not play in this half and will be deleted completely later on!
# []
# []
# SOCCER_FILES/Matchday2/DFL-MAT-00278A/DFL-MAT-00278A-positionen-guest-HT0
# 1  of DFL-MAT-00278A- had to be reflected
# Player 0 did not play in this half and will be deleted completely later on!
# Player 4 did not play in this half and will be deleted completely later on!
# Player 11 did not play in this half and will be deleted completely later on!
# Player 12 did not play in this half and will be deleted completely later on!
# [[1, 'MZ', 50949], [3, 'HL', 18617], [5, 'RA', 45340]]
# [[15, 'LM', 45340], [16, 'DMR', 50949], [17, 'STR', 18617]]
# [[2, 2]]
# [15, 'LM', 45340]
# [5, 'RA', 45340]
# 45340
# 5
# []
# []
# 5
# 15
# ['15_x', '15_y']
# ['5_x', '5_y']
# [[0, 2]]
# [16, 'DMR', 50949]
# [1, 'MZ', 50949]
# 50949
# 1
# [5]
# [15]
# 1
# 16
# ['16_x', '16_y']
# ['1_x', '1_y']
# [[1, 2]]
# [17, 'STR', 18617]
# [3, 'HL', 18617]
# 18617
# 3
# [5, 1]
# [15, 16]
# 3
# 17
# ['17_x', '17_y']
# ['3_x', '3_y']
# SOCCER_FILES/Matchday2/DFL-MAT-00278A/DFL-MAT-00278A-positionen-home-HT1
# 1  of DFL-MAT-00278A- had to be reflected
# Player 2 did not play in this half and will be deleted completely later on!
# Player 3 did not play in this half and will be deleted completely later on!
# Player 5 did not play in this half and will be deleted completely later on!
# Player 11 did not play in this half and will be deleted completely later on!
# [[4, 'DMR', 53298], [15, 'STZ', 49544], [16, 'ORM', 24260]]
# [[6, 'ORM', 24260], [10, 'DML', 53298], [14, 'STZ', 49544]]
# [[2, 2]]
# [6, 'ORM', 24260]
# [16, 'ORM', 24260]
# 24260
# 16
# []
# []
# 16
# 6
# ['6_x', '6_y']
# ['16_x', '16_y']
# [[0, 2]]
# [10, 'DML', 53298]
# [4, 'DMR', 53298]
# 53298
# 4
# [16]
# [6]
# 4
# 10
# ['10_x', '10_y']
# ['4_x', '4_y']
# [[1, 2]]
# [14, 'STZ', 49544]
# [15, 'STZ', 49544]
# 49544
# 15
# [16, 4]
# [6, 10]
# 15
# 14
# ['14_x', '14_y']
# ['15_x', '15_y']
# SOCCER_FILES/Matchday2/DFL-MAT-00278A/DFL-MAT-00278A-positionen-guest-HT1
# 1  of DFL-MAT-00278A- had to be reflected
# 2
# DFL-MAT-00278B
# DFL-MAT-00278B-
# Player 1 did not play in this half and will be deleted completely later on!
# Player 5 did not play in this half and will be deleted completely later on!
# Player 6 did not play in this half and will be deleted completely later on!
# Player 11 did not play in this half and will be deleted completely later on!
# Player 12 did not play in this half and will be deleted completely later on!
# Player 13 did not play in this half and will be deleted completely later on!
# Player 16 did not play in this half and will be deleted completely later on!
# []
# []
# SOCCER_FILES/Matchday2/DFL-MAT-00278B/DFL-MAT-00278B-positionen-home-HT0
# Player 0 did not play in this half and will be deleted completely later on!
# Player 2 did not play in this half and will be deleted completely later on!
# Player 3 did not play in this half and will be deleted completely later on!
# Player 8 did not play in this half and will be deleted completely later on!
# Player 10 did not play in this half and will be deleted completely later on!
# Player 12 did not play in this half and will be deleted completely later on!
# Player 17 did not play in this half and will be deleted completely later on!
# []
# []
# SOCCER_FILES/Matchday2/DFL-MAT-00278B/DFL-MAT-00278B-positionen-guest-HT0
# Player 1 did not play in this half and will be deleted completely later on!
# Player 5 did not play in this half and will be deleted completely later on!
# Player 12 did not play in this half and will be deleted completely later on!
# Player 13 did not play in this half and will be deleted completely later on!
# [[10, 'DML', 55293], [15, 'STZ', 35400], [17, 'LV', 50605]]
# [[6, 'DMZ', 55293], [11, 'STZ', 50605], [16, 'ORM', 35400]]
# [[0, 2]]
# [6, 'DMZ', 55293]
# [10, 'DML', 55293]
# 55293
# 10
# []
# []
# 10
# 6
# ['6_x', '6_y']
# ['10_x', '10_y']
# [[2, 2]]
# [11, 'STZ', 50605]
# [17, 'LV', 50605]
# 50605
# 17
# [10]
# [6]
# 17
# 11
# ['11_x', '11_y']
# ['17_x', '17_y']
# [[1, 2]]
# [16, 'ORM', 35400]
# [15, 'STZ', 35400]
# 35400
# 15
# [10, 17]
# [6, 11]
# 15
# 16
# ['16_x', '16_y']
# ['15_x', '15_y']
# SOCCER_FILES/Matchday2/DFL-MAT-00278B/DFL-MAT-00278B-positionen-home-HT1
# Player 0 did not play in this half and will be deleted completely later on!
# Player 2 did not play in this half and will be deleted completely later on!
# Player 3 did not play in this half and will be deleted completely later on!
# Player 16 did not play in this half and will be deleted completely later on!
# Player 17 did not play in this half and will be deleted completely later on!
# [[4, 'ZO', 49973], [14, 'DML', 71250]]
# [[10, 'DML', 71250], [12, 'DMR', 49973]]
# [[1, 2]]
# [10, 'DML', 71250]
# [14, 'DML', 71250]
# 71250
# 14
# []
# []
# 14
# 10
# ['10_x', '10_y']
# ['14_x', '14_y']
# [[0, 2]]
# [12, 'DMR', 49973]
# [4, 'ZO', 49973]
# 49973
# 4
# [14]
# [10]
# 4
# 12
# ['12_x', '12_y']
# ['4_x', '4_y']
# SOCCER_FILES/Matchday2/DFL-MAT-00278B/DFL-MAT-00278B-positionen-guest-HT1
# 2
# DFL-MAT-00278C
# DFL-MAT-00278C-
# 0  of DFL-MAT-00278C- had to be reflected
# Player 2 did not play in this half and will be deleted completely later on!
# Player 3 did not play in this half and will be deleted completely later on!
# Player 4 did not play in this half and will be deleted completely later on!
# Player 5 did not play in this half and will be deleted completely later on!
# Player 7 did not play in this half and will be deleted completely later on!
# Player 10 did not play in this half and will be deleted completely later on!
# Player 14 did not play in this half and will be deleted completely later on!
# []
# []
# SOCCER_FILES/Matchday2/DFL-MAT-00278C/DFL-MAT-00278C-positionen-home-HT0
# 0  of DFL-MAT-00278C- had to be reflected
# Player 1 did not play in this half and will be deleted completely later on!
# Player 4 did not play in this half and will be deleted completely later on!
# Player 7 did not play in this half and will be deleted completely later on!
# Player 13 did not play in this half and will be deleted completely later on!
# Player 16 did not play in this half and will be deleted completely later on!
# Player 17 did not play in this half and will be deleted completely later on!
# [[3, 'RV', 10480]]
# [[8, 'IVL', 10480]]
# [[0, 2]]
# [8, 'IVL', 10480]
# [3, 'RV', 10480]
# 10480
# 3
# []
# []
# 3
# 8
# ['8_x', '8_y']
# ['3_x', '3_y']
# SOCCER_FILES/Matchday2/DFL-MAT-00278C/DFL-MAT-00278C-positionen-guest-HT0
# 0  of DFL-MAT-00278C- had to be reflected
# Player 3 did not play in this half and will be deleted completely later on!
# Player 4 did not play in this half and will be deleted completely later on!
# Player 5 did not play in this half and will be deleted completely later on!
# Player 7 did not play in this half and will be deleted completely later on!
# [[6, 'DMR', 36769], [11, 'RM', 53223], [13, 'HST', 31759]]
# [[2, 'RM', 53223], [10, 'HST', 31759], [14, 'DML', 36769]]
# [[1, 2]]
# [2, 'RM', 53223]
# [11, 'RM', 53223]
# 53223
# 11
# []
# []
# 11
# 2
# ['2_x', '2_y']
# ['11_x', '11_y']
# [[2, 2]]
# [10, 'HST', 31759]
# [13, 'HST', 31759]
# 31759
# 13
# [11]
# [2]
# 13
# 10
# ['10_x', '10_y']
# ['13_x', '13_y']
# [[0, 2]]
# [14, 'DML', 36769]
# [6, 'DMR', 36769]
# 36769
# 6
# [11, 13]
# [2, 10]
# 6
# 14
# ['14_x', '14_y']
# ['6_x', '6_y']
# SOCCER_FILES/Matchday2/DFL-MAT-00278C/DFL-MAT-00278C-positionen-home-HT1
# Player 3 did not play in this half and will be deleted completely later on!
# Player 4 did not play in this half and will be deleted completely later on!
# Player 13 did not play in this half and will be deleted completely later on!
# Player 16 did not play in this half and will be deleted completely later on!
# Player 17 did not play in this half and will be deleted completely later on!
# [[0, 'ZO', 66097], [5, 'STZ', 28666]]
# [[1, 'ZO', 28666], [7, 'STZ', 66097]]
# [[1, 2]]
# [1, 'ZO', 28666]
# [5, 'STZ', 28666]
# 28666
# 5
# []
# []
# 5
# 1
# ['1_x', '1_y']
# ['5_x', '5_y']
# [[0, 2]]
# [7, 'STZ', 66097]
# [0, 'ZO', 66097]
# 66097
# 0
# [5]
# [1]
# 0
# 7
# ['7_x', '7_y']
# ['0_x', '0_y']
# SOCCER_FILES/Matchday2/DFL-MAT-00278C/DFL-MAT-00278C-positionen-guest-HT1
# 2
# DFL-MAT-00278D
# DFL-MAT-00278D-
# 0  of DFL-MAT-00278D- had to be reflected
# Player 2 did not play in this half and will be deleted completely later on!
# Player 4 did not play in this half and will be deleted completely later on!
# Player 6 did not play in this half and will be deleted completely later on!
# Player 8 did not play in this half and will be deleted completely later on!
# Player 9 did not play in this half and will be deleted completely later on!
# Player 15 did not play in this half and will be deleted completely later on!
# Player 17 did not play in this half and will be deleted completely later on!
# []
# []
# SOCCER_FILES/Matchday2/DFL-MAT-00278D/DFL-MAT-00278D-positionen-home-HT0
# ...
# Player 10 did not play in this half and will be deleted completely later on!
# Player 16 did not play in this half and will be deleted completely later on!
# [[4, 'LM', 35710]]
# [[15, 'STL', 35710]]
# [[0, 2]]
# [15, 'STL', 35710]
# [4, 'LM', 35710]
# 35710
# 4
# []
# []
# 4
# 15
# ['15_x', '15_y']
# ['4_x', '4_y']
# SOCCER_FILES/Matchday34/DFL-MAT-0027G9/DFL-MAT-0027G9-positionen-home-HT1
# Player 2 did not play in this half and will be deleted completely later on!
# Player 9 did not play in this half and will be deleted completely later on!
# Player 11 did not play in this half and will be deleted completely later on!
# Player 17 did not play in this half and will be deleted completely later on!
# [[1, 'LV', 37886], [12, 'STL', 40871], [15, 'STR', 50485]]
# [[4, 'STR', 50485], [8, 'STL', 40871], [13, 'RV', 37886]]
# [[2, 2]]
# [4, 'STR', 50485]
# [15, 'STR', 50485]
# 50485
# 15
# []
# []
# 15
# 4
# ['4_x', '4_y']
# ['15_x', '15_y']
# [[1, 2]]
# [8, 'STL', 40871]
# [12, 'STL', 40871]
# 40871
# 12
# [15]
# [4]
# 12
# 8
# ['8_x', '8_y']
# ['12_x', '12_y']
# [[0, 2]]
# [13, 'RV', 37886]
# [1, 'LV', 37886]
# 37886
# 1
# [15, 12]
# [4, 8]
# 1
# 13
# ['13_x', '13_y']
# ['1_x', '1_y']
# SOCCER_FILES/Matchday34/DFL-MAT-0027G9/DFL-MAT-0027G9-positionen-guest-HT1
# 34
# DFL-MAT-0027GA
# DFL-MAT-0027GA-
# Player 1 did not play in this half and will be deleted completely later on!
# Player 8 did not play in this half and will be deleted completely later on!
# Player 11 did not play in this half and will be deleted completely later on!
# Player 13 did not play in this half and will be deleted completely later on!
# Player 15 did not play in this half and will be deleted completely later on!
# Player 16 did not play in this half and will be deleted completely later on!
# Player 17 did not play in this half and will be deleted completely later on!
# []
# []
# SOCCER_FILES/Matchday34/DFL-MAT-0027GA/DFL-MAT-0027GA-positionen-home-HT0
# Player 1 did not play in this half and will be deleted completely later on!
# Player 3 did not play in this half and will be deleted completely later on!
# Player 5 did not play in this half and will be deleted completely later on!
# Player 6 did not play in this half and will be deleted completely later on!
# Player 11 did not play in this half and will be deleted completely later on!
# Player 16 did not play in this half and will be deleted completely later on!
# [[9, 'RV', 26802]]
# [[10, 'LV', 26802]]
# [[0, 2]]
# [10, 'LV', 26802]
# [9, 'RV', 26802]
# 26802
# 9
# []
# []
# 9
# 10
# ['10_x', '10_y']
# ['9_x', '9_y']
# SOCCER_FILES/Matchday34/DFL-MAT-0027GA/DFL-MAT-0027GA-positionen-guest-HT0
# 1  of DFL-MAT-0027GA- had to be reflected
# Player 1 did not play in this half and will be deleted completely later on!
# Player 8 did not play in this half and will be deleted completely later on!
# Player 11 did not play in this half and will be deleted completely later on!
# Player 17 did not play in this half and will be deleted completely later on!
# [[6, 'LM', 50876], [7, 'RM', 67237], [12, 'STL', 64141]]
# [[13, 'ORM', 67237], [15, 'ZO', 64141], [16, 'OLM', 50876]]
# [[1, 2]]
# [13, 'ORM', 67237]
# [7, 'RM', 67237]
# 67237
# 7
# []
# []
# 7
# 13
# ['13_x', '13_y']
# ['7_x', '7_y']
# [[2, 2]]
# [15, 'ZO', 64141]
# [12, 'STL', 64141]
# 64141
# 12
# [7]
# [13]
# 12
# 15
# ['15_x', '15_y']
# ['12_x', '12_y']
# [[0, 2]]
# [16, 'OLM', 50876]
# [6, 'LM', 50876]
# 50876
# 6
# [7, 12]
# [13, 15]
# 6
# 16
# ['16_x', '16_y']
# ['6_x', '6_y']
# SOCCER_FILES/Matchday34/DFL-MAT-0027GA/DFL-MAT-0027GA-positionen-home-HT1
# 1  of DFL-MAT-0027GA- had to be reflected
# Player 1 did not play in this half and will be deleted completely later on!
# Player 3 did not play in this half and will be deleted completely later on!
# Player 6 did not play in this half and will be deleted completely later on!
# Player 9 did not play in this half and will be deleted completely later on!
# Player 11 did not play in this half and will be deleted completely later on!
# [[8, 'IVL', 44310], [15, 'ORM', 24394]]
# [[5, 'OLM', 44310], [16, 'STR', 24394]]
# [[0, 2]]
# [5, 'OLM', 44310]
# [8, 'IVL', 44310]
# 44310
# 8
# []
# []
# 8
# 5
# ['5_x', '5_y']
# ['8_x', '8_y']
# [[1, 2]]
# [16, 'STR', 24394]
# [15, 'ORM', 24394]
# 24394
# 15
# [8]
# [5]
# 15
# 16
# ['16_x', '16_y']
# ['15_x', '15_y']
# SOCCER_FILES/Matchday34/DFL-MAT-0027GA/DFL-MAT-0027GA-positionen-guest-HT1
# 1  of DFL-MAT-0027GA- had to be reflected
# 34
# DFL-MAT-0027GB
# DFL-MAT-0027GB-
# Player 0 did not play in this half and will be deleted completely later on!
# Player 2 did not play in this half and will be deleted completely later on!
# Player 3 did not play in this half and will be deleted completely later on!
# Player 4 did not play in this half and will be deleted completely later on!
# Player 5 did not play in this half and will be deleted completely later on!
# Player 12 did not play in this half and will be deleted completely later on!
# Player 13 did not play in this half and will be deleted completely later on!
# []
# []
# SOCCER_FILES/Matchday34/DFL-MAT-0027GB/DFL-MAT-0027GB-positionen-home-HT0
# Player 0 did not play in this half and will be deleted completely later on!
# Player 1 did not play in this half and will be deleted completely later on!
# Player 2 did not play in this half and will be deleted completely later on!
# Player 5 did not play in this half and will be deleted completely later on!
# Player 8 did not play in this half and will be deleted completely later on!
# Player 11 did not play in this half and will be deleted completely later on!
# Player 15 did not play in this half and will be deleted completely later on!
# []
# []
# SOCCER_FILES/Matchday34/DFL-MAT-0027GB/DFL-MAT-0027GB-positionen-guest-HT0
# 1  of DFL-MAT-0027GB- had to be reflected
# Player 3 did not play in this half and will be deleted completely later on!
# Player 4 did not play in this half and will be deleted completely later on!
# Player 5 did not play in this half and will be deleted completely later on!
# Player 13 did not play in this half and will be deleted completely later on!
# [[7, 'ZO', 60820], [10, 'DMR', 37843], [16, 'ORM', 27953]]
# [[0, 'ZO', 60820], [2, 'ORM', 37843], [12, 'ORM', 27953]]
# [[0, 2]]
# [0, 'ZO', 60820]
# [7, 'ZO', 60820]
# 60820
# 7
# []
# []
# 7
# 0
# ['0_x', '0_y']
# ['7_x', '7_y']
# [[1, 2]]
# [2, 'ORM', 37843]
# [10, 'DMR', 37843]
# 37843
# 10
# [7]
# [0]
# 10
# 2
# ['2_x', '2_y']
# ['10_x', '10_y']
# [[2, 2]]
# [12, 'ORM', 27953]
# [16, 'ORM', 27953]
# 27953
# 16
# [7, 10]
# [0, 2]
# 16
# 12
# ['12_x', '12_y']
# ['16_x', '16_y']
# SOCCER_FILES/Matchday34/DFL-MAT-0027GB/DFL-MAT-0027GB-positionen-home-HT1
# 1  of DFL-MAT-0027GB- had to be reflected
# Player 0 did not play in this half and will be deleted completely later on!
# Player 1 did not play in this half and will be deleted completely later on!
# Player 5 did not play in this half and will be deleted completely later on!
# Player 13 did not play in this half and will be deleted completely later on!
# Player 15 did not play in this half and will be deleted completely later on!
# [[7, 'RV', 46086], [9, 'ZO', 58381]]
# [[2, 'ORM', 46086], [8, 'ZO', 58381]]
# [[0, 2]]
# [2, 'ORM', 46086]
# [7, 'RV', 46086]
# 46086
# 7
# []
# []
# 7
# 2
# ['2_x', '2_y']
# ['7_x', '7_y']
# [[1, 2]]
# [8, 'ZO', 58381]
# [9, 'ZO', 58381]
# 58381
# 9
# [7]
# [2]
# 9
# 8
# ['8_x', '8_y']
# ['9_x', '9_y']
# SOCCER_FILES/Matchday34/DFL-MAT-0027GB/DFL-MAT-0027GB-positionen-guest-HT1
# 1  of DFL-MAT-0027GB- had to be reflected
# 34
# DFL-MAT-0027GC
# DFL-MAT-0027GC-
# 0  of DFL-MAT-0027GC- had to be reflected
# Player 1 did not play in this half and will be deleted completely later on!
# Player 3 did not play in this half and will be deleted completely later on!
# Player 4 did not play in this half and will be deleted completely later on!
# Player 5 did not play in this half and will be deleted completely later on!
# Player 9 did not play in this half and will be deleted completely later on!
# Player 12 did not play in this half and will be deleted completely later on!
# Player 13 did not play in this half and will be deleted completely later on!
# []
# []
# SOCCER_FILES/Matchday34/DFL-MAT-0027GC/DFL-MAT-0027GC-positionen-home-HT0
# 0  of DFL-MAT-0027GC- had to be reflected
# Player 3 did not play in this half and will be deleted completely later on!
# Player 4 did not play in this half and will be deleted completely later on!
# Player 5 did not play in this half and will be deleted completely later on!
# Player 7 did not play in this half and will be deleted completely later on!
# Player 9 did not play in this half and will be deleted completely later on!
# Player 10 did not play in this half and will be deleted completely later on!
# Player 14 did not play in this half and will be deleted completely later on!
# []
# []
# SOCCER_FILES/Matchday34/DFL-MAT-0027GC/DFL-MAT-0027GC-positionen-guest-HT0
# 0  of DFL-MAT-0027GC- had to be reflected
# Player 3 did not play in this half and will be deleted completely later on!
# Player 4 did not play in this half and will be deleted completely later on!
# Player 5 did not play in this half and will be deleted completely later on!
# Player 9 did not play in this half and will be deleted completely later on!
# [[2, 'IVZ', 65665], [11, 'OLM', 46409], [16, 'ORM', 59942]]
# [[1, 'ORM', 46409], [12, 'HL', 65665], [13, 'OLM', 59942]]
# [[1, 2]]
# [1, 'ORM', 46409]
# [11, 'OLM', 46409]
# 46409
# 11
# []
# []
# 11
# 1
# ['1_x', '1_y']
# ['11_x', '11_y']
# [[0, 2]]
# [12, 'HL', 65665]
# [2, 'IVZ', 65665]
# 65665
# 2
# [11]
# [1]
# 2
# 12
# ['12_x', '12_y']
# ['2_x', '2_y']
# [[2, 2]]
# [13, 'OLM', 59942]
# [16, 'ORM', 59942]
# 59942
# 16
# [11, 2]
# [1, 12]
# 16
# 13
# ['13_x', '13_y']
# ['16_x', '16_y']
# SOCCER_FILES/Matchday34/DFL-MAT-0027GC/DFL-MAT-0027GC-positionen-home-HT1
# Player 3 did not play in this half and will be deleted completely later on!
# Player 5 did not play in this half and will be deleted completely later on!
# Player 7 did not play in this half and will be deleted completely later on!
# Player 9 did not play in this half and will be deleted completely later on!
# Player 14 did not play in this half and will be deleted completely later on!
# [[6, 'RM', 67235], [8, 'STZ', 60206], [11, 'LM', 47660], [17, 'DMZ', 26349]]
# [[4, 'RM', 67235], [10, 'STZ', 60206]]
# more suboffs as subons Probably just a red card or injury post 3 subs
# [[0, 2]]
# [4, 'RM', 67235]
# [6, 'RM', 67235]
# 67235
# 6
# []
# []
# 6
# 4
# ['4_x', '4_y']
# ['6_x', '6_y']
# [[1, 2]]
# [10, 'STZ', 60206]
# [8, 'STZ', 60206]
# 60206
# 8
# [6]
# [4]
# 8
# 10
# ['10_x', '10_y']
# ['8_x', '8_y']
# SOCCER_FILES/Matchday34/DFL-MAT-0027GC/DFL-MAT-0027GC-positionen-guest-HT1
# 34
# DFL-MAT-0027GD
# DFL-MAT-0027GD-
# Player 2 did not play in this half and will be deleted completely later on!
# Player 6 did not play in this half and will be deleted completely later on!
# Player 7 did not play in this half and will be deleted completely later on!
# Player 10 did not play in this half and will be deleted completely later on!
# Player 13 did not play in this half and will be deleted completely later on!
# Player 14 did not play in this half and will be deleted completely later on!
# Player 16 did not play in this half and will be deleted completely later on!
# []
# []
# SOCCER_FILES/Matchday34/DFL-MAT-0027GD/DFL-MAT-0027GD-positionen-home-HT0
# Player 1 did not play in this half and will be deleted completely later on!
# Player 4 did not play in this half and will be deleted completely later on!
# Player 5 did not play in this half and will be deleted completely later on!
# Player 10 did not play in this half and will be deleted completely later on!
# Player 11 did not play in this half and will be deleted completely later on!
# Player 12 did not play in this half and will be deleted completely later on!
# Player 14 did not play in this half and will be deleted completely later on!
# []
# []
# SOCCER_FILES/Matchday34/DFL-MAT-0027GD/DFL-MAT-0027GD-positionen-guest-HT0
# 1  of DFL-MAT-0027GD- had to be reflected
# Player 6 did not play in this half and will be deleted completely later on!
# Player 7 did not play in this half and will be deleted completely later on!
# Player 10 did not play in this half and will be deleted completely later on!
# Player 13 did not play in this half and will be deleted completely later on!
# Player 16 did not play in this half and will be deleted completely later on!
# [[9, 'RM', 29821], [11, 'HR', 30228]]
# [[2, 'DMZ', 29821], [14, 'HR', 30228]]
# [[0, 2]]
# [2, 'DMZ', 29821]
# [9, 'RM', 29821]
# 29821
# 9
# []
# []
# 9
# 2
# ['2_x', '2_y']
# ['9_x', '9_y']
# [[1, 2]]
# [14, 'HR', 30228]
# [11, 'HR', 30228]
# 30228
# 11
# [9]
# [2]
# 11
# 14
# ['14_x', '14_y']
# ['11_x', '11_y']
# SOCCER_FILES/Matchday34/DFL-MAT-0027GD/DFL-MAT-0027GD-positionen-home-HT1
# 1  of DFL-MAT-0027GD- had to be reflected
# Player 1 did not play in this half and will be deleted completely later on!
# Player 4 did not play in this half and will be deleted completely later on!
# Player 5 did not play in this half and will be deleted completely later on!
# Player 12 did not play in this half and will be deleted completely later on!
# [[0, 'STL', 66730], [9, 'STR', 71648], [15, 'LV', 10372]]
# [[10, 'OLM', 10372], [11, 'STL', 66730], [14, 'LM', 71648]]
# [[2, 2]]
# [10, 'OLM', 10372]
# [15, 'LV', 10372]
# 10372
# 15
# []
# []
# 15
# 10
# ['10_x', '10_y']
# ['15_x', '15_y']
# [[0, 2]]
# [11, 'STL', 66730]
# [0, 'STL', 66730]
# 66730
# 0
# [15]
# [10]
# 0
# 11
# ['11_x', '11_y']
# ['0_x', '0_y']
# [[1, 2]]
# [14, 'LM', 71648]
# [9, 'STR', 71648]
# 71648
# 9
# [15, 0]
# [10, 11]
# 9
# 14
# ['14_x', '14_y']
# ['9_x', '9_y']
# SOCCER_FILES/Matchday34/DFL-MAT-0027GD/DFL-MAT-0027GD-positionen-guest-HT1
# 1  of DFL-MAT-0027GD- had to be reflected
# 34
# DFL-MAT-0027GE
# DFL-MAT-0027GE-
# Player 7 did not play in this half and will be deleted completely later on!
# Player 8 did not play in this half and will be deleted completely later on!
# Player 9 did not play in this half and will be deleted completely later on!
# Player 11 did not play in this half and will be deleted completely later on!
# Player 14 did not play in this half and will be deleted completely later on!
# Player 16 did not play in this half and will be deleted completely later on!
# Player 17 did not play in this half and will be deleted completely later on!
# []
# []
# SOCCER_FILES/Matchday34/DFL-MAT-0027GE/DFL-MAT-0027GE-positionen-home-HT0
# Player 0 did not play in this half and will be deleted completely later on!
# Player 2 did not play in this half and will be deleted completely later on!
# Player 3 did not play in this half and will be deleted completely later on!
# Player 4 did not play in this half and will be deleted completely later on!
# Player 8 did not play in this half and will be deleted completely later on!
# Player 12 did not play in this half and will be deleted completely later on!
# Player 15 did not play in this half and will be deleted completely later on!
# []
# []
# SOCCER_FILES/Matchday34/DFL-MAT-0027GE/DFL-MAT-0027GE-positionen-guest-HT0
# 1  of DFL-MAT-0027GE- had to be reflected
# Player 7 did not play in this half and will be deleted completely later on!
# Player 8 did not play in this half and will be deleted completely later on!
# Player 14 did not play in this half and will be deleted completely later on!
# Player 17 did not play in this half and will be deleted completely later on!
# [[1, 'LM', 25138], [4, 'DML', 37895], [6, 'ORM', 47481]]
# [[9, 'OLM', 47481], [11, 'STZ', 37895], [16, 'IVL', 25138]]
# [[2, 2]]
# [9, 'OLM', 47481]
# [6, 'ORM', 47481]
# 47481
# 6
# []
# []
# 6
# 9
# ['9_x', '9_y']
# ['6_x', '6_y']
# [[1, 2]]
# [11, 'STZ', 37895]
# [4, 'DML', 37895]
# 37895
# 4
# [6]
# [9]
# 4
# 11
# ['11_x', '11_y']
# ['4_x', '4_y']
# [[0, 2]]
# [16, 'IVL', 25138]
# [1, 'LM', 25138]
# 25138
# 1
# [6, 4]
# [9, 11]
# 1
# 16
# ['16_x', '16_y']
# ['1_x', '1_y']
# SOCCER_FILES/Matchday34/DFL-MAT-0027GE/DFL-MAT-0027GE-positionen-home-HT1
# 1  of DFL-MAT-0027GE- had to be reflected
# Player 0 did not play in this half and will be deleted completely later on!
# Player 3 did not play in this half and will be deleted completely later on!
# Player 4 did not play in this half and will be deleted completely later on!
# Player 8 did not play in this half and will be deleted completely later on!
# Player 15 did not play in this half and will be deleted completely later on!
# [[14, 'STL', 31245], [16, 'STR', 56006]]
# [[2, 'STZ', 56006], [12, 'ORM', 31245]]
# [[1, 2]]
# [2, 'STZ', 56006]
# [16, 'STR', 56006]
# 56006
# 16
# []
# []
# 16
# 2
# ['2_x', '2_y']
# ['16_x', '16_y']
# [[0, 2]]
# [12, 'ORM', 31245]
# [14, 'STL', 31245]
# 31245
# 14
# [16]
# [2]
# 14
# 12
# ['12_x', '12_y']
# ['14_x', '14_y']
# SOCCER_FILES/Matchday34/DFL-MAT-0027GE/DFL-MAT-0027GE-positionen-guest-HT1
# 1  of DFL-MAT-0027GE- had to be reflected

# %%
mn

# %%
game_overview = pd.read_csv('Output/GameOverview2.csv')


ROOT = os.getcwd() # returns current working directory of a process.

pos_file = (r"PositionData/DFL_04_02_positions_raw_DFL-COM-000001_DFL-MAT-00278B.xml") # creates a raw string which treats backslash (\) as a literal character. 




mn = pos_file[-18:-4] # cut the matchname!
md = str(game_overview.Matchday[game_overview.MI_Name == mn].iloc[0])
print(md)
position_file = pos_file
# find the matching match info
matching_files = glob.glob(''.join(['Matchinfo/*',mn, '*']))
if len(matching_files) != 1:   # should be only one matchinfo file matching the game 
    print('Matchinfo Error')
else:
    matchinfo = matching_files[0]
    # parse data via floodlight parser
    xy_objects, possession_objects, ballstatus_objects, teamsheets, pitch = dfl.read_position_data_xml(filepath_positions=position_file,
              filepath_mat_info=matchinfo)
    write_dfl_xml_to_soccer(xy_objects, teamsheets, md, game_overview, mn) 
    # this function includes the saving of the files!
# Out:
# 2
# DFL-MAT-00278B
# DFL-MAT-00278B-
# Player 1 did not play in this half and will be deleted completely later on!
# Player 5 did not play in this half and will be deleted completely later on!
# Player 6 did not play in this half and will be deleted completely later on!
# Player 11 did not play in this half and will be deleted completely later on!
# Player 12 did not play in this half and will be deleted completely later on!
# Player 13 did not play in this half and will be deleted completely later on!
# Player 16 did not play in this half and will be deleted completely later on!
# []
# []
# SOCCER_FILES/Matchday2/DFL-MAT-00278B/DFL-MAT-00278B-positionen-home-HT0
# Player 0 did not play in this half and will be deleted completely later on!
# Player 2 did not play in this half and will be deleted completely later on!
# Player 3 did not play in this half and will be deleted completely later on!
# Player 8 did not play in this half and will be deleted completely later on!
# Player 10 did not play in this half and will be deleted completely later on!
# Player 12 did not play in this half and will be deleted completely later on!
# Player 17 did not play in this half and will be deleted completely later on!
# []
# []
# SOCCER_FILES/Matchday2/DFL-MAT-00278B/DFL-MAT-00278B-positionen-guest-HT0
# 1  of DFL-MAT-00278B- had to be reflected
# Player 1 did not play in this half and will be deleted completely later on!
# Player 5 did not play in this half and will be deleted completely later on!
# Player 12 did not play in this half and will be deleted completely later on!
# Player 13 did not play in this half and will be deleted completely later on!
# [[10, 'DML', 55293], [15, 'STZ', 35400], [17, 'LV', 50605]]
# [[6, 'DMZ', 55293], [11, 'STZ', 50605], [16, 'ORM', 35400]]
# [[0, 2]]
# [6, 'DMZ', 55293]
# [10, 'DML', 55293]
# 55293
# 10
# []
# []
# 10
# 6
# ['6_x', '6_y']
# ['10_x', '10_y']
# [[2, 2]]
# [11, 'STZ', 50605]
# [17, 'LV', 50605]
# 50605
# 17
# [10]
# [6]
# 17
# 11
# ['11_x', '11_y']
# ['17_x', '17_y']
# [[1, 2]]
# [16, 'ORM', 35400]
# [15, 'STZ', 35400]
# 35400
# 15
# [10, 17]
# [6, 11]
# 15
# 16
# ['16_x', '16_y']
# ['15_x', '15_y']
# SOCCER_FILES/Matchday2/DFL-MAT-00278B/DFL-MAT-00278B-positionen-home-HT1
# 1  of DFL-MAT-00278B- had to be reflected
# Player 0 did not play in this half and will be deleted completely later on!
# Player 2 did not play in this half and will be deleted completely later on!
# Player 3 did not play in this half and will be deleted completely later on!
# Player 16 did not play in this half and will be deleted completely later on!
# Player 17 did not play in this half and will be deleted completely later on!
# [[4, 'ZO', 49973], [14, 'DML', 71250]]
# [[10, 'DML', 71250], [12, 'DMR', 49973]]
# [[1, 2]]
# [10, 'DML', 71250]
# [14, 'DML', 71250]
# 71250
# 14
# []
# []
# 14
# 10
# ['10_x', '10_y']
# ['14_x', '14_y']
# [[0, 2]]
# [12, 'DMR', 49973]
# [4, 'ZO', 49973]
# 49973
# 4
# [14]
# [10]
# 4
# 12
# ['12_x', '12_y']
# ['4_x', '4_y']
# SOCCER_FILES/Matchday2/DFL-MAT-00278B/DFL-MAT-00278B-positionen-guest-HT1
# 1  of DFL-MAT-00278B- had to be reflected

# %%
game_overview.head()
# Out:
#    Unnamed: 0                        MI_Date                      Home  \
# 0           0  2016-08-26T20:30:00.000+02:00         FC Bayern München
# 1           1  2016-08-27T15:30:00.000+02:00         Borussia Dortmund
# 2           2  2016-08-27T18:30:00.000+02:00  Borussia Mönchengladbach
# 3           3  2016-08-28T15:30:00.000+02:00                Hertha BSC
# 4           4  2016-08-27T15:30:00.000+02:00                1. FC Köln
#
#                   Away Final_Score  Matchday         MI_Name  NameCorrect?  \
# 0     SV Werder Bremen         6:0         1  DFL-MAT-00277X          True
# 1      1. FSV Mainz 05         2:1         1  DFL-MAT-00277Y          True
# 2  Bayer 04 Leverkusen         2:1         1  DFL-MAT-00277Z          True
# 3  Sport-Club Freiburg         2:1         1  DFL-MAT-002780          True
# 4      SV Darmstadt 98         2:0         1  DFL-MAT-002781          True
#
#          Pos_Name            Opta_Date           Opta_Name Red_card Retired  \
# 0  DFL-MAT-00277X  2016-08-26T19:30:00  f24-22-2016-861390    False   False
# 1  DFL-MAT-00277Y  2016-08-27T14:30:00  f24-22-2016-861391    False   False
# 2  DFL-MAT-00277Z  2016-08-27T17:30:00  f24-22-2016-861392    False    True
# 3  DFL-MAT-002780  2016-08-28T14:30:00  f24-22-2016-861393    False   False
# 4  DFL-MAT-002781  2016-08-27T14:30:00  f24-22-2016-861394    False    True
#
#   Direction_Home_HT1 Direction_Home_HT2 Direction_Away_HT1 Direction_Away_HT2  \
# 0      Right to Left      Left to Right      Left to Right      Right to Left
# 1      Left to Right      Right to Left      Right to Left      Left to Right
# 2      Left to Right      Right to Left      Right to Left      Left to Right
# 3      Right to Left      Left to Right      Left to Right      Right to Left
# 4      Right to Left      Left to Right      Left to Right      Right to Left
#
#    Pos_Home  Pos_Away
# 0        71        30
# 1        74        26
# 2        51        50
# 3        55        45
# 4        59        41
